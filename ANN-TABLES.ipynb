# %%
"""
    @Sathish-V

    Beginner-level ANN(Artificial Neural Network) Project

    Description:

        The project helps beginners to understand how ANN works , here I've taken a simple Regression based
    use case which is 2nd table, there are 2 hidden-layers each with 10-units and the weights are
    initialized by the he_uniform distribution. Activation function used here is ReLu.

"""

#import necessary modules

import numpy as np
from tensorflow import keras
from keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt


#preparing dataset which is table for number '2'

x = np.array([[x, 2] for x in range(1, 100001)])
y = np.array([x * 2 for x in range(1, 100001)])

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=32)


#Building ANN model

model = keras.Sequential()

model.add(layers.Dense(units=10, kernel_initializer="he_uniform", activation="relu", input_dim=2))

model.add(layers.Dense(units=10, kernel_initializer="he_uniform", activation="relu"))

model.add(layers.Dense(units=1, activation="linear"))

model.compile(optimizer="adam", loss="mean_absolute_error", metrics=["mean_absolute_error"])

#Fit the model

model_details = model.fit(x_train, y_train, validation_split=0.15, epochs=100)

#prediction

prediction = model.predict(x_test)

#Calculating the metrics

pred = np.array([x[0] for x in prediction])

mae = mean_absolute_error(pred, y_test)
print("Mean Absolute Error:", mae)


#Plotting the actual and predicted values corresponding to the independent variable

input = np.array([[x , 2] for x in range(1, 21)])

ouput = model.predict(input)

y_axis = [x[0] for x in ouput]

plt.subplot(1, 2, 1)
plt.scatter(input[:, 0], input[:, 0] * 2)
plt.title("Actual-value")
plt.xlabel("2 x i")
plt.ylabel("product of 2")

plt.subplot(1, 2, 2)
plt.scatter(input[:, 0], ouput)
plt.title("Predicted-value")
plt.xlabel("2 x i")
plt.ylabel("product of 2")

plt.show()
# Out:
# Epoch 1/100
# 1860/1860 [==============================] - 5s 2ms/step - loss: 2426.3943 - mean_absolute_error: 2426.3943 - val_loss: 8.8390 - val_mean_absolute_error: 8.8390
# Epoch 2/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 92.1435 - mean_absolute_error: 92.1435 - val_loss: 112.8458 - val_mean_absolute_error: 112.8458
# Epoch 3/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 81.5961 - mean_absolute_error: 81.5961 - val_loss: 279.5622 - val_mean_absolute_error: 279.5622
# Epoch 4/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 94.6868 - mean_absolute_error: 94.6868 - val_loss: 278.9829 - val_mean_absolute_error: 278.9829
# Epoch 5/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 88.8492 - mean_absolute_error: 88.8492 - val_loss: 54.0949 - val_mean_absolute_error: 54.0949
# Epoch 6/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 91.5168 - mean_absolute_error: 91.5168 - val_loss: 5.5368 - val_mean_absolute_error: 5.5368
# Epoch 7/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 88.0765 - mean_absolute_error: 88.0765 - val_loss: 259.7308 - val_mean_absolute_error: 259.7308
# Epoch 8/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 84.9127 - mean_absolute_error: 84.9127 - val_loss: 70.3655 - val_mean_absolute_error: 70.3655
# Epoch 9/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 84.4438 - mean_absolute_error: 84.4438 - val_loss: 155.1054 - val_mean_absolute_error: 155.1054
# Epoch 10/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 105.1600 - mean_absolute_error: 105.1600 - val_loss: 213.4654 - val_mean_absolute_error: 213.4654
# Epoch 11/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 94.8316 - mean_absolute_error: 94.8316 - val_loss: 54.8733 - val_mean_absolute_error: 54.8733
# Epoch 12/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 89.2135 - mean_absolute_error: 89.2135 - val_loss: 237.9001 - val_mean_absolute_error: 237.9001
# Epoch 13/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 82.2163 - mean_absolute_error: 82.2163 - val_loss: 108.7018 - val_mean_absolute_error: 108.7018
# Epoch 14/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 85.4268 - mean_absolute_error: 85.4268 - val_loss: 88.0981 - val_mean_absolute_error: 88.0981
# Epoch 15/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 90.9985 - mean_absolute_error: 90.9985 - val_loss: 167.7359 - val_mean_absolute_error: 167.7359
# Epoch 16/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 91.2941 - mean_absolute_error: 91.2941 - val_loss: 44.0352 - val_mean_absolute_error: 44.0352
# Epoch 17/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 82.7233 - mean_absolute_error: 82.7233 - val_loss: 40.0513 - val_mean_absolute_error: 40.0513
# Epoch 18/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 85.2369 - mean_absolute_error: 85.2369 - val_loss: 25.5472 - val_mean_absolute_error: 25.5472
# Epoch 19/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 77.0919 - mean_absolute_error: 77.0919 - val_loss: 94.2901 - val_mean_absolute_error: 94.2901
# Epoch 20/100
# 1860/1860 [==============================] - 5s 2ms/step - loss: 81.3858 - mean_absolute_error: 81.3858 - val_loss: 14.1577 - val_mean_absolute_error: 14.1577
# Epoch 21/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 78.9995 - mean_absolute_error: 78.9995 - val_loss: 115.0744 - val_mean_absolute_error: 115.0744
# Epoch 22/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 94.3076 - mean_absolute_error: 94.3076 - val_loss: 14.6890 - val_mean_absolute_error: 14.6890
# Epoch 23/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 88.8976 - mean_absolute_error: 88.8976 - val_loss: 126.2046 - val_mean_absolute_error: 126.2046
# Epoch 24/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 87.5848 - mean_absolute_error: 87.5848 - val_loss: 117.2080 - val_mean_absolute_error: 117.2080
# Epoch 25/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 82.2934 - mean_absolute_error: 82.2934 - val_loss: 318.5893 - val_mean_absolute_error: 318.5893
# Epoch 26/100
# 1860/1860 [==============================] - 5s 2ms/step - loss: 81.8610 - mean_absolute_error: 81.8610 - val_loss: 260.4316 - val_mean_absolute_error: 260.4316
# Epoch 27/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 75.3971 - mean_absolute_error: 75.3971 - val_loss: 1.5804 - val_mean_absolute_error: 1.5804
# Epoch 28/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 87.5680 - mean_absolute_error: 87.5680 - val_loss: 99.5184 - val_mean_absolute_error: 99.5184
# Epoch 29/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 92.2982 - mean_absolute_error: 92.2982 - val_loss: 78.0579 - val_mean_absolute_error: 78.0579
# Epoch 30/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 73.0931 - mean_absolute_error: 73.0931 - val_loss: 156.6442 - val_mean_absolute_error: 156.6442
# Epoch 31/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 79.2727 - mean_absolute_error: 79.2727 - val_loss: 74.8930 - val_mean_absolute_error: 74.8930
# Epoch 32/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 83.6395 - mean_absolute_error: 83.6395 - val_loss: 167.7930 - val_mean_absolute_error: 167.7930
# Epoch 33/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 78.9727 - mean_absolute_error: 78.9727 - val_loss: 56.4293 - val_mean_absolute_error: 56.4293
# Epoch 34/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 88.2004 - mean_absolute_error: 88.2004 - val_loss: 53.0341 - val_mean_absolute_error: 53.0341
# Epoch 35/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 82.7022 - mean_absolute_error: 82.7022 - val_loss: 126.2266 - val_mean_absolute_error: 126.2266
# Epoch 36/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 83.5692 - mean_absolute_error: 83.5692 - val_loss: 138.4400 - val_mean_absolute_error: 138.4400
# Epoch 37/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 80.2215 - mean_absolute_error: 80.2215 - val_loss: 25.3519 - val_mean_absolute_error: 25.3519
# Epoch 38/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 92.0506 - mean_absolute_error: 92.0506 - val_loss: 159.3804 - val_mean_absolute_error: 159.3804
# Epoch 39/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 78.3539 - mean_absolute_error: 78.3539 - val_loss: 71.6105 - val_mean_absolute_error: 71.6105
# Epoch 40/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 85.8609 - mean_absolute_error: 85.8609 - val_loss: 70.9063 - val_mean_absolute_error: 70.9063
# Epoch 41/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 85.4497 - mean_absolute_error: 85.4497 - val_loss: 80.6416 - val_mean_absolute_error: 80.6416
# Epoch 42/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 81.4430 - mean_absolute_error: 81.4430 - val_loss: 96.1118 - val_mean_absolute_error: 96.1118
# Epoch 43/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 90.2561 - mean_absolute_error: 90.2561 - val_loss: 42.0278 - val_mean_absolute_error: 42.0278
# Epoch 44/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 86.1390 - mean_absolute_error: 86.1390 - val_loss: 124.9380 - val_mean_absolute_error: 124.9380
# Epoch 45/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 84.6483 - mean_absolute_error: 84.6483 - val_loss: 186.1488 - val_mean_absolute_error: 186.1488
# Epoch 46/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 84.9317 - mean_absolute_error: 84.9317 - val_loss: 162.5280 - val_mean_absolute_error: 162.5280
# Epoch 47/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 82.3285 - mean_absolute_error: 82.3285 - val_loss: 8.6137 - val_mean_absolute_error: 8.6137
# Epoch 48/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 79.9210 - mean_absolute_error: 79.9210 - val_loss: 67.4595 - val_mean_absolute_error: 67.4595
# Epoch 49/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 84.3801 - mean_absolute_error: 84.3801 - val_loss: 153.7863 - val_mean_absolute_error: 153.7863
# Epoch 50/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 83.0493 - mean_absolute_error: 83.0493 - val_loss: 54.0378 - val_mean_absolute_error: 54.0378
# Epoch 51/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 84.9210 - mean_absolute_error: 84.9210 - val_loss: 13.8789 - val_mean_absolute_error: 13.8789
# Epoch 52/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 81.0040 - mean_absolute_error: 81.0040 - val_loss: 29.6469 - val_mean_absolute_error: 29.6469
# Epoch 53/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 83.0923 - mean_absolute_error: 83.0923 - val_loss: 33.2841 - val_mean_absolute_error: 33.2841
# Epoch 54/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 84.9493 - mean_absolute_error: 84.9493 - val_loss: 25.0038 - val_mean_absolute_error: 25.0038
# Epoch 55/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 84.6984 - mean_absolute_error: 84.6984 - val_loss: 135.5091 - val_mean_absolute_error: 135.5091
# Epoch 56/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 80.0917 - mean_absolute_error: 80.0917 - val_loss: 88.5750 - val_mean_absolute_error: 88.5750
# Epoch 57/100
# 1860/1860 [==============================] - 5s 2ms/step - loss: 86.7532 - mean_absolute_error: 86.7532 - val_loss: 105.1233 - val_mean_absolute_error: 105.1233
# Epoch 58/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 90.2888 - mean_absolute_error: 90.2888 - val_loss: 19.3728 - val_mean_absolute_error: 19.3728
# Epoch 59/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 87.1640 - mean_absolute_error: 87.1640 - val_loss: 52.9615 - val_mean_absolute_error: 52.9615
# Epoch 60/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 89.3887 - mean_absolute_error: 89.3887 - val_loss: 92.7784 - val_mean_absolute_error: 92.7784
# Epoch 61/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 88.6289 - mean_absolute_error: 88.6289 - val_loss: 5.2403 - val_mean_absolute_error: 5.2403
# Epoch 62/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 81.9831 - mean_absolute_error: 81.9831 - val_loss: 14.0995 - val_mean_absolute_error: 14.0995
# Epoch 63/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 75.3379 - mean_absolute_error: 75.3379 - val_loss: 123.5989 - val_mean_absolute_error: 123.5989
# Epoch 64/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 77.3857 - mean_absolute_error: 77.3857 - val_loss: 45.5937 - val_mean_absolute_error: 45.5937
# Epoch 65/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 93.9405 - mean_absolute_error: 93.9405 - val_loss: 28.0074 - val_mean_absolute_error: 28.0074
# Epoch 66/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 81.3574 - mean_absolute_error: 81.3574 - val_loss: 13.9207 - val_mean_absolute_error: 13.9207
# Epoch 67/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 92.3590 - mean_absolute_error: 92.3590 - val_loss: 32.5432 - val_mean_absolute_error: 32.5432
# Epoch 68/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 86.6451 - mean_absolute_error: 86.6451 - val_loss: 30.1046 - val_mean_absolute_error: 30.1046
# Epoch 69/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 80.1069 - mean_absolute_error: 80.1069 - val_loss: 1.6482 - val_mean_absolute_error: 1.6482
# Epoch 70/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 73.0951 - mean_absolute_error: 73.0951 - val_loss: 84.9118 - val_mean_absolute_error: 84.9118
# Epoch 71/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 75.6701 - mean_absolute_error: 75.6701 - val_loss: 99.2240 - val_mean_absolute_error: 99.2240
# Epoch 72/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 85.3888 - mean_absolute_error: 85.3888 - val_loss: 185.9171 - val_mean_absolute_error: 185.9171
# Epoch 73/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 77.5493 - mean_absolute_error: 77.5493 - val_loss: 151.5904 - val_mean_absolute_error: 151.5904
# Epoch 74/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 78.2738 - mean_absolute_error: 78.2738 - val_loss: 120.4635 - val_mean_absolute_error: 120.4635
# Epoch 75/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 79.9253 - mean_absolute_error: 79.9253 - val_loss: 114.1681 - val_mean_absolute_error: 114.1681
# Epoch 76/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 85.4003 - mean_absolute_error: 85.4003 - val_loss: 76.3230 - val_mean_absolute_error: 76.3230
# Epoch 77/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 85.7990 - mean_absolute_error: 85.7990 - val_loss: 31.3819 - val_mean_absolute_error: 31.3819
# Epoch 78/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 80.7352 - mean_absolute_error: 80.7352 - val_loss: 136.5672 - val_mean_absolute_error: 136.5672
# Epoch 79/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 87.0514 - mean_absolute_error: 87.0514 - val_loss: 132.5051 - val_mean_absolute_error: 132.5051
# Epoch 80/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 89.0889 - mean_absolute_error: 89.0889 - val_loss: 76.7431 - val_mean_absolute_error: 76.7431
# Epoch 81/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 85.4204 - mean_absolute_error: 85.4204 - val_loss: 15.7816 - val_mean_absolute_error: 15.7816
# Epoch 82/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 81.8705 - mean_absolute_error: 81.8705 - val_loss: 74.7990 - val_mean_absolute_error: 74.7990
# Epoch 83/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 87.8268 - mean_absolute_error: 87.8268 - val_loss: 44.0006 - val_mean_absolute_error: 44.0006
# Epoch 84/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 90.4941 - mean_absolute_error: 90.4941 - val_loss: 118.0548 - val_mean_absolute_error: 118.0548
# Epoch 85/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 78.6596 - mean_absolute_error: 78.6596 - val_loss: 56.2318 - val_mean_absolute_error: 56.2318
# Epoch 86/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 84.1170 - mean_absolute_error: 84.1170 - val_loss: 76.5051 - val_mean_absolute_error: 76.5051
# Epoch 87/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 83.9794 - mean_absolute_error: 83.9794 - val_loss: 205.6249 - val_mean_absolute_error: 205.6249
# Epoch 88/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 80.6986 - mean_absolute_error: 80.6986 - val_loss: 108.2531 - val_mean_absolute_error: 108.2531
# Epoch 89/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 79.8131 - mean_absolute_error: 79.8131 - val_loss: 77.4927 - val_mean_absolute_error: 77.4927
# Epoch 90/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 87.9751 - mean_absolute_error: 87.9751 - val_loss: 9.3794 - val_mean_absolute_error: 9.3794
# Epoch 91/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 82.8767 - mean_absolute_error: 82.8767 - val_loss: 177.7940 - val_mean_absolute_error: 177.7940
# Epoch 92/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 79.9979 - mean_absolute_error: 79.9979 - val_loss: 78.8700 - val_mean_absolute_error: 78.8700
# Epoch 93/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 85.7460 - mean_absolute_error: 85.7460 - val_loss: 32.4234 - val_mean_absolute_error: 32.4234
# Epoch 94/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 89.7441 - mean_absolute_error: 89.7441 - val_loss: 0.5477 - val_mean_absolute_error: 0.5477
# Epoch 95/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 83.6189 - mean_absolute_error: 83.6189 - val_loss: 48.7381 - val_mean_absolute_error: 48.7381
# Epoch 96/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 88.3305 - mean_absolute_error: 88.3305 - val_loss: 61.0926 - val_mean_absolute_error: 61.0926
# Epoch 97/100
# 1860/1860 [==============================] - 5s 2ms/step - loss: 79.2018 - mean_absolute_error: 79.2018 - val_loss: 21.6149 - val_mean_absolute_error: 21.6149
# Epoch 98/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 91.5932 - mean_absolute_error: 91.5932 - val_loss: 220.2064 - val_mean_absolute_error: 220.2064
# Epoch 99/100
# 1860/1860 [==============================] - 4s 2ms/step - loss: 82.7153 - mean_absolute_error: 82.7153 - val_loss: 20.8992 - val_mean_absolute_error: 20.8992
# Epoch 100/100
# 1860/1860 [==============================] - 5s 3ms/step - loss: 97.0302 - mean_absolute_error: 97.0302 - val_loss: 7.0955 - val_mean_absolute_error: 7.0955
# 938/938 [==============================] - 1s 2ms/step
# Mean Absolute Error: 7.08694892633756
# 1/1 [==============================] - 0s 21ms/step

# %%
from google.colab import drive
drive.mount('/content/drive')
